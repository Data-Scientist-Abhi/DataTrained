# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# Avocado is a fruit consumed by people heavily in the United States.

# %% [markdown]
# ### Content:

# %% [markdown]
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.

# %% [markdown]
# ### Importing Libraries :-

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Impoting Dataset :-

# %%
data=pd.read_csv('avocado.csv')
data.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %% [markdown]
# ### Checking the shape of data using .shape funcion:

# %%
data.shape
# Out:
# (18249, 14)

# %%
data.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
data=data.drop(columns=['Unnamed: 0','Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.7+ MB

# %%
data.isnull().sum()
# Out:
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
data.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data[['type', 'region',]]=data[['type', 'region',]].apply(le.fit_transform)

# %%
data.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region
# 0     8603.62       93.25          0.0     0  2015       0
# 1     9408.07       97.49          0.0     0  2015       0
# 2     8042.21      103.14          0.0     0  2015       0
# 3     5677.40      133.76          0.0     0  2015       0
# 4     5986.26      197.69          0.0     0  2015       0

# %%
data.year.value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
data.region.value_counts()
# Out:
# 47    338
# 31    338
# 6     338
# 37    338
# 21    338
# 5     338
# 52    338
# 36    338
# 20    338
# 4     338
# 51    338
# 35    338
# 19    338
# 3     338
# 50    338
# 34    338
# 18    338
# 2     338
# 49    338
# 33    338
# 17    338
# 1     338
# 48    338
# 32    338
# 16    338
# 22    338
# 38    338
# 7     338
# 27    338
# 15    338
# 46    338
# 30    338
# 14    338
# 45    338
# 29    338
# 13    338
# 44    338
# 28    338
# 12    338
# 43    338
# 11    338
# 23    338
# 42    338
# 26    338
# 10    338
# 41    338
# 25    338
# 9     338
# 40    338
# 24    338
# 8     338
# 39    338
# 0     338
# 53    335
# Name: region, dtype: int64

# %%
def convert(x):
  if x<=1.10:
    return 0   #Low price
  elif x<=2.20:
    return 1 #average price
  elif x<=3.30:
    return 2 #high price

data['AveragePrice']=data['AveragePrice'].apply(convert)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data=data,x='4225')
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Count'>

# %%
plt.figure(figsize=(25,20))
plotnumber=1
for i in data:
    if plotnumber<=15:
        plt.subplot(3,5,plotnumber)
        sns.scatterplot(x=data[i],y=data['AveragePrice'])
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(25,20))
plotnumber=1
for i in data:
    if plotnumber<=16:
        plt.subplot(3,5,plotnumber)
        sns.distplot(x=data[i])
        plt.xlabel(i)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(25,40),facecolor='white')
plotnumber=1
for i in data:
    if plotnumber<=30:
        ax=plt.subplot(10,3,plotnumber)
        sns.boxplot(data[i])
        plt.xlabel(i,fontsize=15)
    plotnumber+=1
plt.show()

# %%
from scipy.stats import zscore
z_Score=zscore(data)
abs_z_score=np.abs(z_Score)
filtering_entry=(abs_z_score<3).all(axis=1)
data=data[filtering_entry]

# %%
plt.figure(figsize=(25,20))
plotnumber=1
for i in data:
    if plotnumber<=16:
        plt.subplot(3,5,plotnumber)
        sns.distplot(x=data[i])
        plt.xlabel(i)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(25,40),facecolor='white')
plotnumber=1
for i in data:
    if plotnumber<=30:
        ax=plt.subplot(10,3,plotnumber)
        sns.boxplot(data[i])
        plt.xlabel(i,fontsize=15)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn_r')
# Out:
# <AxesSubplot:>

# %%
data.skew()
# Out:
# AveragePrice   -0.443172
# Total Volume    3.782060
# 4046            4.928850
# 4225            4.472729
# 4770            5.137120
# Total Bags      4.082103
# Small Bags      4.238647
# Large Bags      5.072468
# XLarge Bags     6.159391
# type           -0.052210
# year            0.220792
# region          0.005773
# dtype: float64

# %%
q=data['Total Volume'].quantile(.99)
cleaned_data=data[data['Total Volume']<q]

q=cleaned_data['4046'].quantile(.98)
cleaned_data=cleaned_data[cleaned_data['4046']<q]

q=cleaned_data['4225'].quantile(.99)
cleaned_data=cleaned_data[cleaned_data['4225']<q]

q=cleaned_data['Total Bags'].quantile(.98)
cleaned_data=cleaned_data[cleaned_data['Total Bags']<q]

q=cleaned_data['Large Bags'].quantile(.98)
cleaned_data=cleaned_data[cleaned_data['Large Bags']<q]

q=cleaned_data['XLarge Bags'].quantile(.99)
cleaned_data=cleaned_data[cleaned_data['XLarge Bags']<q]

# %%
cleaned_data.shape
# Out:
# (16236, 12)

# %%
plt.figure(figsize=(25,40),facecolor='white')
plotnumber=1
for i in data:
    if plotnumber<=30:
        ax=plt.subplot(10,3,plotnumber)
        sns.boxplot(data[i])
        plt.xlabel(i,fontsize=15)
    plotnumber+=1
plt.show()

# %%
x=data.drop('AveragePrice',axis=1)
y=data['AveragePrice']

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
x_new=scale.fit_transform(x)
x_new
# Out:
# array([[-0.38989656, -0.34801998, -0.27640517, ..., -1.02644331,
#         -1.21490801, -1.69861255],
#        [-0.39916634, -0.34884725, -0.30107759, ..., -1.02644331,
#         -1.21490801, -1.69861255],
#        [-0.33643122, -0.34857241, -0.13893085, ..., -1.02644331,
#         -1.21490801, -1.69861255],
#        ...,
#        [-0.43988189, -0.3476658 , -0.40711129, ...,  0.97423793,
#          1.97914269,  1.74255245],
#        [-0.43746684, -0.34689958, -0.40578355, ...,  0.97423793,
#          1.97914269,  1.74255245],
#        [-0.43619481, -0.34377924, -0.40735425, ...,  0.97423793,
#          1.97914269,  1.74255245]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# Libraries for model selection
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score

# %%
max_=0
maxr=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=.25,random_state=i) # passed non scaled data because in decisiontree there is no need of scale data
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc= accuracy_score(y_test,pred)
    if acc>max_:
        max_=acc
        maxr=i
print('max accuracy score:',max_,'\nmax random state:',maxr)
# Out:
# max accuracy score: 0.791497975708502
# max random state: 192

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((13336, 11), (13336,), (4446, 11), (4446,))

# %%
x_train,x_test,y_train,y_test=train_test_split(x_new,y,test_size=.25,random_state=maxr)

# %%
# LogisticRegression model  
lr=LogisticRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print('Result by LogisticRegression')
print('\naccuracy score:',accuracy_score(y_test,pred))
print('\nclassification report:\n\n',classification_report(y_test,pred))
print('confusioon matrix:\n',confusion_matrix(y_test,pred))
# Out:
# Result by LogisticRegression
#
# accuracy score: 0.791497975708502
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.75      0.42      0.54      1099
#            1       0.80      0.95      0.87      3208
#            2       0.00      0.00      0.00       139
#
#     accuracy                           0.79      4446
#    macro avg       0.52      0.46      0.47      4446
# weighted avg       0.76      0.79      0.76      4446
#
# confusioon matrix:
#  [[ 463  636    0]
#  [ 152 3056    0]
#  [   0  139    0]]

# %%
# decisiontree classifier model  
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
print('Result by Decision Tree Classifier')
print('\naccuracy score:',accuracy_score(y_test,pred))
print('\nclassification report:\n\n',classification_report(y_test,pred))
print('confusioon matrix:\n',confusion_matrix(y_test,pred))
# Out:
# Result by Decision Tree Classifier
#
# accuracy score: 0.8524516419253262
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.78      0.75      0.77      1099
#            1       0.89      0.90      0.90      3208
#            2       0.45      0.50      0.47       139
#
#     accuracy                           0.85      4446
#    macro avg       0.71      0.72      0.71      4446
# weighted avg       0.85      0.85      0.85      4446
#
# confusioon matrix:
#  [[ 823  275    1]
#  [ 228 2898   82]
#  [   1   69   69]]

# %%
# KNeighbors Classifier model
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
pred=knc.predict(x_test)
print('Result by KNeighbors Classifier')
print('\naccuracy score:',accuracy_score(y_test,pred))
print('\nclassification report:\n\n',classification_report(y_test,pred))
print('confusioon matrix:\n',confusion_matrix(y_test,pred))
# Out:
# Result by KNeighbors Classifier
#
# accuracy score: 0.8852901484480432
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.86      0.74      0.80      1099
#            1       0.90      0.95      0.92      3208
#            2       0.68      0.62      0.65       139
#
#     accuracy                           0.89      4446
#    macro avg       0.82      0.77      0.79      4446
# weighted avg       0.88      0.89      0.88      4446
#
# confusioon matrix:
#  [[ 809  290    0]
#  [ 127 3041   40]
#  [   0   53   86]]

# %%
# Support Vector Classifier model
svc=SVC()
svc.fit(x_train,y_train)
pred=svc.predict(x_test)
print('Result by Support Vector Classifier')
print('\naccuracy score:',accuracy_score(y_test,pred))
print('\nclassification report:\n\n',classification_report(y_test,pred))
print('confusioon matrix:\n',confusion_matrix(y_test,pred))
# Out:
# Result by Support Vector Classifier
#
# accuracy score: 0.835357624831309
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.83      0.57      0.68      1099
#            1       0.84      0.96      0.89      3208
#            2       0.00      0.00      0.00       139
#
#     accuracy                           0.84      4446
#    macro avg       0.56      0.51      0.52      4446
# weighted avg       0.81      0.84      0.81      4446
#
# confusioon matrix:
#  [[ 631  468    0]
#  [ 125 3083    0]
#  [   0  139    0]]

# %%
# RandomForest Classifier model
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
pred=rfc.predict(x_test)
print('Result by RandomForest Classifier')
print('\naccuracy score:',accuracy_score(y_test,pred))
print('\nclassification report:\n\n',classification_report(y_test,pred))
print('confusioon matrix:\n',confusion_matrix(y_test,pred))
# Out:
# Result by RandomForest Classifier
#
# accuracy score: 0.9014844804318488
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.88      0.80      0.83      1099
#            1       0.91      0.96      0.93      3208
#            2       0.81      0.45      0.58       139
#
#     accuracy                           0.90      4446
#    macro avg       0.87      0.74      0.78      4446
# weighted avg       0.90      0.90      0.90      4446
#
# confusioon matrix:
#  [[ 875  224    0]
#  [ 123 3070   15]
#  [   0   76   63]]

# %%
# AdaBoost Classifier model
abc=AdaBoostClassifier()
abc.fit(x_train,y_train)
pred=abc.predict(x_test)
print('Result by AdaBoost Classifier')
print('\naccuracy score:',accuracy_score(y_test,pred))
print('\nclassification report:\n\n',classification_report(y_test,pred))
print('confusioon matrix:\n',confusion_matrix(y_test,pred))
# Out:
# Result by AdaBoost Classifier
#
# accuracy score: 0.7393162393162394
#
# classification report:
#
#                precision    recall  f1-score   support
#
#            0       0.53      0.70      0.61      1099
#            1       0.85      0.78      0.81      3208
#            2       0.39      0.19      0.26       139
#
#     accuracy                           0.74      4446
#    macro avg       0.59      0.56      0.56      4446
# weighted avg       0.76      0.74      0.74      4446
#
# confusioon matrix:
#  [[ 772  326    1]
#  [ 679 2488   41]
#  [   0  112   27]]

# %%
m=[lr,dtc,knc,svc,rfc,abc] #scaled for other models for cross validation
for i in m:
    scr_=cross_val_score(i,x_new,y,cv=15)
    print(i)
    print('cross validation score:',scr_.mean(),'\n')
# Out:
# LogisticRegression()
# cross validation score: 0.7233897581488676
#
# DecisionTreeClassifier()
# cross validation score: 0.4981082625947826
#
# KNeighborsClassifier()
# cross validation score: 0.2117824691726969
#
# SVC()
# cross validation score: 0.6647710395305759
#
# RandomForestClassifier()
# cross validation score: 0.595084186583749
#
# AdaBoostClassifier()
# cross validation score: 0.6951138339227225

# %%
lr.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
#hyperparameter tuning for rfc
parameters={'solver':['newton-cg', 'lbfgs', 'liblinear'],'penalty':['l1','l2'],'C':[10, 1.0, 0.1, 0.01]}

gs=GridSearchCV(lr,parameters)
gs.fit(x_train,y_train)
print('\n--------------------------Logistic Classifier Hyperparameter Tuning------------------')
print('best estimators:\n',gs.best_estimator_)

lr_=gs.best_estimator_ # direct applying best estimators
lr_.fit(x_train,y_train)
pred=lr_.predict(x_test)
print(f'\n\naccuracy score:{accuracy_score(y_test,pred)*100:.2f}%\n')
print(f'\nconfusion_matrix:\n{confusion_matrix(y_test,pred)}\n')
print(f'\nclassification_report:\n{pd.DataFrame(classification_report(y_test,pred,output_dict=True))}')
# Out:
# --------------------------Logistic Classifier Hyperparameter Tuning------------------
# best estimators:
#  LogisticRegression(C=10, penalty='l1', solver='liblinear')
#
#
# accuracy score:79.19%
#
#
# confusion_matrix:
# [[ 441  658    0]
#  [ 128 3080    0]
#  [   0  139    0]]
#
#
# classification_report:
#                      0            1      2  accuracy    macro avg  \
# precision     0.775044     0.794429    0.0  0.791948     0.523158
# recall        0.401274     0.960100    0.0  0.791948     0.453791
# f1-score      0.528777     0.869442    0.0  0.791948     0.466073
# support    1099.000000  3208.000000  139.0  0.791948  4446.000000
#
#            weighted avg
# precision      0.764800
# recall         0.791948
# f1-score       0.758052
# support     4446.000000

# %% [markdown]
# ### Saving model :

# %%
import pickle
filename='red_wine_best.pkl'
pickle.dump(lr_,open(filename,'wb'))
